# %% [markdown]
# ## Exercise 2
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import sqlite3
with sqlite3.connect("hw1-population.db") as db:
    data = pd.read_sql_query("SELECT * FROM population", db)

# %%
# What columns does it have? (2 points)
list(data.columns)
# Out:
# ['name', 'age', 'weight', 'eyecolor']

# %%
# How many rows (think: people) does it have? (2 points)
data.shape[0]
# Out:
# 152361

# %%
summary = data.describe()

# %%
summary
# Out:
#                  age         weight
# count  152361.000000  152361.000000
# mean       39.510528      60.884134
# std        24.152760      18.411824
# min         0.000748       3.382084
# 25%        19.296458      58.300135
# 50%        38.468955      68.000000
# 75%        57.623245      71.529860
# max        99.991547     100.435793

# %%
age_mean = summary['age']['mean']
age_sd = summary['age']['std']
wgt_mean = summary['weight']['mean']
wgt_sd = summary['weight']['std']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(data['age'],bins=20, rwidth=.9)#,histtype='stepfilled')
# plt.vlines(age_mean+age_sd,0, 0.014,colors='y')
# plt.vlines(age_mean-age_sd,0, 0.014,colors='b')
plt.title('Frequency distribution of ages')#'mean+2sd','mean-2sd',
plt.xlabel('age')
plt.show()

# %%
plt.hist(data['weight'],bins=20, rwidth=.9)#,histtype='stepfilled')
plt.title('Frequency distribution of weights')#'mean+2sd','mean-2sd',
plt.xlabel('weight')
plt.show()

# %%
x = data['age']
y = data['weight']
plt.scatter(x, y, s=3)
plt.xlabel('age')
plt.ylabel('weight')
plt.show()

# %%
data[(data['age']>40)&(data['weight']<25)]
# Out:
#                 name   age  weight eyecolor
# 537  Anthony Freeman  41.3    21.7    green
